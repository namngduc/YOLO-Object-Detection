# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# %cd /content
# !unzip /content/drive/'My Drive'/Yolo/darknet.zip

# %%
# %cd /content/darknet
# Out:
# /content/darknet

# %%
# !ls
# !sed -i 's/ARCH= -gencode arch=compute_70,code=[sm_70,compute_70]/ARCH= -gencode arch=compute_60,code=sm_60/g' Makefile
# Out:
# backup		   drone.data	libdarknet.a   python	  test.txt
# cfg		   drone.names	libdarknet.so  README.md  train.txt
# darknet		   examples	Makefile       results	  yolo_opencv.py
# darknet53.conv.74  images	obj	       scripts
# data		   include	obj-detection  src

# %%
# !make
# !chmod +x ./darknet
# Out:
# make: Nothing to be done for 'all'.

# %%
# !rm /content/darknet/backup -r
# !ln -s /content/drive/'My Drive'/Yolo/backup /content/darknet

# %%
# %cd /content/darknet
# !./darknet detector train drone.data cfg/yolov3.cfg
# Out:
# Region 82 Avg IOU: 0.883446, Class: 0.999834, Obj: 0.979352, No Obj: 0.002378, .5R: 1.000000, .75R: 1.000000,  count: 4
# Region 94 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000000, .5R: -nan, .75R: -nan,  count: 0
# Region 106 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000000, .5R: -nan, .75R: -nan,  count: 0
# Region 82 Avg IOU: 0.805439, Class: 0.999550, Obj: 0.813197, No Obj: 0.002336, .5R: 1.000000, .75R: 0.750000,  count: 4
# Region 94 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000012, .5R: -nan, .75R: -nan,  count: 0
# Region 106 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000000, .5R: -nan, .75R: -nan,  count: 0
# Region 82 Avg IOU: 0.822824, Class: 0.999945, Obj: 0.994165, No Obj: 0.002183, .5R: 1.000000, .75R: 0.500000,  count: 4
# Region 94 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000000, .5R: -nan, .75R: -nan,  count: 0
# Region 106 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000001, .5R: -nan, .75R: -nan,  count: 0
# ...

# %%
# !nvidia-smi
# Out:
# Sun Dec 22 01:49:32 2019
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.44       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   31C    P0    26W / 250W |      0MiB / 16280MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# ...

# %%
# !kill -9 -1
